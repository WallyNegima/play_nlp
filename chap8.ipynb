# %%
import json

import dbpediaknowledge


synonyms = dbpediaknowledge.get_synonyms('アメリカ合衆国')
print(json.dumps(synonyms, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "United States"
#     },
#     {
#         "term": "米合衆国"
#     },
#     {
#         "term": "米国"
#     },
#     {
#         "term": "アメリカ人"
#     },
#     {
#         "term": "U.S.A."
#     },
#     {
#         "term": "亜米利加"
#     },
#     {
#         "term": "亜米利加合衆国"
#     },
#     {
#         "term": "米利堅"
#     },
#     {
#         "term": "U.S."
#     },
#     {
#         "term": "ユナイテッドステイツ"
#     },
#     {
#         "term": "United States of America"
#     },
#     {
#         "term": "Usa"
#     },
#     {
#         "term": "全米"
#     },
#     {
#         "term": "アメリカ合衆国人"
#     },
#     {
#         "term": "アメリカ系"
#     },
#     {
#         "term": "米国人"
#     },
#     {
#         "term": "アメリカ"
#     },
#     {
#         "term": "USA"
#     },
#     {
#         "term": "美國"
#     },
#     {
#         "term": "America"
#     }
# ]

# %%
import dbpediaknowledge


text1 = 'アメリカ合衆国'
text2 = 'イギリス'
similarity = dbpediaknowledge.calc_similarity(text1, text2)
print(similarity, text1, text2)
text1 = 'アメリカ合衆国'
text2 = '日本'
similarity = dbpediaknowledge.calc_similarity(text1, text2)
print(similarity, text1, text2)
# Out:
# 0.6675620175680795 アメリカ合衆国 イギリス
# 0.3211308144666283 アメリカ合衆国 日本

# %%
import json

import dbpediaknowledge


text = 'アメリカ合衆国'
population = dbpediaknowledge.get_population(text)
print(population)
# Out:
# 316942000

# %%
import json

import wordnetknowledge


synonyms = wordnetknowledge.get_synonyms('アメリカ合衆国')
print(json.dumps(synonyms, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "ＵＳ"
#     },
#     {
#         "term": "ＵＳＡ"
#     },
#     {
#         "term": "アメリカ"
#     },
#     {
#         "term": "Ｕ．Ｓ．Ａ．"
#     },
#     {
#         "term": "亜米利加"
#     },
#     {
#         "term": "アメリカ合衆国"
#     },
#     {
#         "term": "合衆国"
#     },
#     {
#         "term": "米"
#     },
#     {
#         "term": "米国"
#     },
#     {
#         "term": "北部諸州"
#     },
#     {
#         "term": "アメリカ合衆国"
#     }
# ]

# %%
import wordnetknowledge


text1 = 'アメリカ合衆国'
text2 = '米国'
similarity = wordnetknowledge.calc_similarity(text1, text2)
print(similarity, text1, text2)
text1 = 'アメリカ合衆国'
text2 = '日本'
similarity = wordnetknowledge.calc_similarity(text1, text2)
print(similarity, text1, text2)
# Out:
# 1.0 アメリカ合衆国 米国
# 0.2 アメリカ合衆国 日本

# %%
import json

import wordnetknowledge

text = '幸福'
results = wordnetknowledge.get_hypernym(text)
print(json.dumps(results, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "フィーリング"
#     },
#     {
#         "term": "心地"
#     },
#     {
#         "term": "心持"
#     },
#     {
#         "term": "心持ち"
#     },
#     {
#         "term": "心緒"
#     },
#     {
#         "term": "念"
#     },
#     {
#         "term": "念い"
#     },
#     {
#         "term": "思"
#     },
#     {
#         "term": "思い"
#     },
#     {
#         "term": "情"
#     },
#     {
#         "term": "想い"
#     },
#     {
#         "term": "感"
#     },
#     {
#         "term": "感じ"
#     },
#     {
#         "term": "感情"
#     },
#     {
#         "term": "気分"
#     },
#     {
#         "term": "気味"
#     },
#     {
#         "term": "気味合"
#     },
#     {
#         "term": "気味合い"
#     },
#     {
#         "term": "気持"
#     },
#     {
#         "term": "気持ち"
#     },
#     {
#         "term": "気色"
#     },
#     {
#         "term": "上景気"
#     },
#     {
#         "term": "成功"
#     },
#     {
#         "term": "振作"
#     },
#     {
#         "term": "栄耀"
#     },
#     {
#         "term": "殷富"
#     },
#     {
#         "term": "殷盛"
#     },
#     {
#         "term": "殷賑"
#     },
#     {
#         "term": "盛況"
#     },
#     {
#         "term": "盛運"
#     },
#     {
#         "term": "繁栄"
#     },
#     {
#         "term": "繁華"
#     },
#     {
#         "term": "興隆"
#     },
#     {
#         "term": "賑わい"
#     },
#     {
#         "term": "隆盛"
#     }
# ]

# %%
import json

import wordnetknowledge

text = '気持ち'
results = wordnetknowledge.get_hyponym(text)
print(json.dumps(results, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "ラブ"
#     },
#     {
#         "term": "いつくしみ"
#     },
#     {
#         "term": "優しさ"
#     },
#     {
#         "term": "優しいこと"
#     },
#     {
#         "term": "好き"
#     },
#     {
#         "term": "好意"
#     },
#     {
#         "term": "情愛"
#     },
#     {
#         "term": "愛"
#     },
#     {
#         "term": "愛心"
#     },
#     {
#         "term": "愛念"
#     },
#     {
#         "term": "愛情"
#     },
#     {
#         "term": "愛情のこもったこと"
#     },
#     {
#         "term": "愛着"
#     },
#     {
#         "term": "慈"
#     },
#     {
#         "term": "慈しみ"
#     },
#     {
#         "term": "慈愛"
#     },
#     {
#         "term": "暖かさ"
#     },
#     {
#         "term": "暖か味"
#     },
#     {
#         "term": "温かさ"
#     },
#     {
#         "term": "温か味"
#     },
#     {
#         "term": "アジテーション"
#     },
#     {
#         "term": "亢奮"
#     },
#     {
#         "term": "動乱"
#     },
#     {
#         "term": "動揺"
#     },
#     {
#         "term": "周章"
#     },
#     {
#         "term": "扇動"
#     },
#     {
#         "term": "撹拌"
#     },
#     {
#         "term": "攪拌"
#     },
#     {
#         "term": "昂奮"
#     },
#     {
#         "term": "煽動"
#     },
#     {
#         "term": "興奮"
#     },
#     {
#         "term": "顫動"
#     },
#     {
#         "term": "アンビバレンス"
#     },
#     {
#         "term": "両面価値"
#     },
#     {
#         "term": "愛憎併存"
#     },
#     {
#         "term": "アパシー"
#     },
#     {
#         "term": "アパテイア"
#     },
#     {
#         "term": "感情鈍麻"
#     },
#     {
#         "term": "一驚"
#     },
#     {
#         "term": "仰天"
#     },
#     {
#         "term": "吃驚"
#     },
#     {
#         "term": "喫驚"
#     },
#     {
#         "term": "愕"
#     },
#     {
#         "term": "愕き"
#     },
#     {
#         "term": "驚"
#     },
#     {
#         "term": "驚き"
#     },
#     {
#         "term": "驚がく"
#     },
#     {
#         "term": "驚嘆"
#     },
#     {
#         "term": "驚愕"
#     },
#     {
#         "term": "冷静"
#     },
#     {
#         "term": "安らぎ"
#     },
#     {
#         "term": "平安"
#     },
#     {
#         "term": "平気"
#     },
#     {
#         "term": "平穏"
#     },
#     {
#         "term": "平静"
#     },
#     {
#         "term": "沈着"
#     },
#     {
#         "term": "落ち着き"
#     },
#     {
#         "term": "静穏"
#     },
#     {
#         "term": "コンプレクス"
#     },
#     {
#         "term": "コンプレックス"
#     },
#     {
#         "term": "デザイア"
#     },
#     {
#         "term": "デザイアー"
#     },
#     {
#         "term": "欲求"
#     },
#     {
#         "term": "渇"
#     },
#     {
#         "term": "渇き"
#     },
#     {
#         "term": "渇求"
#     },
#     {
#         "term": "願望"
#     },
#     {
#         "term": "やけくそ"
#     },
#     {
#         "term": "やけっぱち"
#     },
#     {
#         "term": "失意"
#     },
#     {
#         "term": "失望"
#     },
#     {
#         "term": "悲観"
#     },
#     {
#         "term": "捨鉢"
#     },
#     {
#         "term": "捨て鉢"
#     },
#     {
#         "term": "絶念"
#     },
#     {
#         "term": "絶望"
#     },
#     {
#         "term": "自暴"
#     },
#     {
#         "term": "自暴自棄"
#     },
#     {
#         "term": "自棄"
#     },
#     {
#         "term": "自棄のやん八"
#     },
#     {
#         "term": "不好き"
#     },
#     {
#         "term": "厭さ"
#     },
#     {
#         "term": "厭悪"
#     },
#     {
#         "term": "厭気"
#     },
#     {
#         "term": "反感"
#     },
#     {
#         "term": "嫌い"
#     },
#     {
#         "term": "嫌厭"
#     },
#     {
#         "term": "嫌気"
#     },
#     {
#         "term": "小面憎さ"
#     },
#     {
#         "term": "悪感情"
#     },
#     {
#         "term": "苦手"
#     },
#     {
#         "term": "エモーション"
#     },
#     {
#         "term": "情"
#     },
#     {
#         "term": "情動"
#     },
#     {
#         "term": "情性"
#     },
#     {
#         "term": "情意"
#     },
#     {
#         "term": "情感"
#     },
#     {
#         "term": "感情"
#     },
#     {
#         "term": "強い興味"
#     },
#     {
#         "term": "忘我"
#     },
#     {
#         "term": "情熱"
#     },
#     {
#         "term": "意気ごみ"
#     },
#     {
#         "term": "意気組み"
#     },
#     {
#         "term": "意気込み"
#     },
#     {
#         "term": "気勢"
#     },
#     {
#         "term": "気組み"
#     },
#     {
#         "term": "気込み"
#     },
#     {
#         "term": "熱中"
#     },
#     {
#         "term": "熱心"
#     },
#     {
#         "term": "熱情"
#     },
#     {
#         "term": "熱意"
#     },
#     {
#         "term": "熱気"
#     },
#     {
#         "term": "熱狂"
#     },
#     {
#         "term": "熱血"
#     },
#     {
#         "term": "狂熱"
#     },
#     {
#         "term": "興奮"
#     },
#     {
#         "term": "いき込み"
#     },
#     {
#         "term": "予想"
#     },
#     {
#         "term": "勇気"
#     },
#     {
#         "term": "感謝"
#     },
#     {
#         "term": "有りがたさ"
#     },
#     {
#         "term": "有り難さ"
#     },
#     {
#         "term": "有難さ"
#     },
#     {
#         "term": "謝恩"
#     },
#     {
#         "term": "謝意"
#     },
#     {
#         "term": "引力"
#     },
#     {
#         "term": "荘厳"
#     },
#     {
#         "term": "重力"
#     },
#     {
#         "term": "重要性"
#     },
#     {
#         "term": "仕合わせ"
#     },
#     {
#         "term": "倖"
#     },
#     {
#         "term": "倖せ"
#     },
#     {
#         "term": "幸"
#     },
#     {
#         "term": "幸い"
#     },
#     {
#         "term": "幸福"
#     },
#     {
#         "term": "幸福感"
#     },
#     {
#         "term": "ホウプ"
#     },
#     {
#         "term": "冀望"
#     },
#     {
#         "term": "希望"
#     },
#     {
#         "term": "望み"
#     },
#     {
#         "term": "期待"
#     },
#     {
#         "term": "卑下"
#     },
#     {
#         "term": "謙譲"
#     },
#     {
#         "term": "謙遜"
#     },
#     {
#         "term": "不義理"
#     },
#     {
#         "term": "忘恩"
#     },
#     {
#         "term": "恩知らず"
#     },
#     {
#         "term": "お好"
#     },
#     {
#         "term": "お好み"
#     },
#     {
#         "term": "好き"
#     },
#     {
#         "term": "御好"
#     },
#     {
#         "term": "御好み"
#     },
#     {
#         "term": "傷み"
#     },
#     {
#         "term": "憂苦"
#     },
#     {
#         "term": "痛み"
#     },
#     {
#         "term": "痛苦"
#     },
#     {
#         "term": "苦"
#     },
#     {
#         "term": "苦しさ"
#     },
#     {
#         "term": "苦悩"
#     },
#     {
#         "term": "苦楚"
#     },
#     {
#         "term": "苦痛"
#     },
#     {
#         "term": "苦痛なこと"
#     },
#     {
#         "term": "辛さ"
#     },
#     {
#         "term": "難儀さ"
#     },
#     {
#         "term": "難渋さ"
#     },
#     {
#         "term": "パッション"
#     },
#     {
#         "term": "情熱"
#     },
#     {
#         "term": "激情"
#     },
#     {
#         "term": "熱心さ"
#     },
#     {
#         "term": "熱情"
#     },
#     {
#         "term": "熱烈さ"
#     },
#     {
#         "term": "熱血"
#     },
#     {
#         "term": "熱誠"
#     },
#     {
#         "term": "喜び"
#     },
#     {
#         "term": "大喜び"
#     },
#     {
#         "term": "快"
#     },
#     {
#         "term": "快味"
#     },
#     {
#         "term": "悦び"
#     },
#     {
#         "term": "悦楽"
#     },
#     {
#         "term": "愉快さ"
#     },
#     {
#         "term": "愉楽"
#     },
#     {
#         "term": "慶び"
#     },
#     {
#         "term": "楽しさ"
#     },
#     {
#         "term": "欣び"
#     },
#     {
#         "term": "歓"
#     },
#     {
#         "term": "歓び"
#     },
#     {
#         "term": "歓喜"
#     },
#     {
#         "term": "歓楽"
#     },
#     {
#         "term": "おごり"
#     },
#     {
#         "term": "うぬぼれ"
#     },
#     {
#         "term": "倨傲"
#     },
#     {
#         "term": "傲り"
#     },
#     {
#         "term": "得意"
#     },
#     {
#         "term": "思いあがり"
#     },
#     {
#         "term": "慢心"
#     },
#     {
#         "term": "我ぼめ"
#     },
#     {
#         "term": "我れぼめ"
#     },
#     {
#         "term": "我褒め"
#     },
#     {
#         "term": "我賞め"
#     },
#     {
#         "term": "気位"
#     },
#     {
#         "term": "矜恃"
#     },
#     {
#         "term": "矜持"
#     },
#     {
#         "term": "自尊"
#     },
#     {
#         "term": "自尊心"
#     },
#     {
#         "term": "自慢"
#     },
#     {
#         "term": "自負"
#     },
#     {
#         "term": "自負心"
#     },
#     {
#         "term": "見識"
#     },
#     {
#         "term": "誇"
#     },
#     {
#         "term": "誇り"
#     },
#     {
#         "term": "誇らしさ"
#     },
#     {
#         "term": "驕り"
#     },
#     {
#         "term": "驕傲"
#     },
#     {
#         "term": "驕心"
#     },
#     {
#         "term": "高慢なこと"
#     },
#     {
#         "term": "不仕合せ"
#     },
#     {
#         "term": "不仕合せさ"
#     },
#     {
#         "term": "不仕合わせさ"
#     },
#     {
#         "term": "不幸"
#     },
#     {
#         "term": "不幸さ"
#     },
#     {
#         "term": "不幸せさ"
#     },
#     {
#         "term": "哀しさ"
#     },
#     {
#         "term": "哀情"
#     },
#     {
#         "term": "悲しさ"
#     },
#     {
#         "term": "感じやすさ"
#     },
#     {
#         "term": "感じ易さ"
#     },
#     {
#         "term": "敏感さ"
#     },
#     {
#         "term": "センチメント"
#     },
#     {
#         "term": "センティメント"
#     },
#     {
#         "term": "心地"
#     },
#     {
#         "term": "心情"
#     },
#     {
#         "term": "思い"
#     },
#     {
#         "term": "情感"
#     },
#     {
#         "term": "情緒"
#     },
#     {
#         "term": "情調"
#     },
#     {
#         "term": "想い"
#     },
#     {
#         "term": "感じ"
#     },
#     {
#         "term": "感傷"
#     },
#     {
#         "term": "感情"
#     },
#     {
#         "term": "気分"
#     },
#     {
#         "term": "気味"
#     },
#     {
#         "term": "気持"
#     },
#     {
#         "term": "気持ち"
#     },
#     {
#         "term": "胸懐"
#     },
#     {
#         "term": "胸間"
#     },
#     {
#         "term": "セックス"
#     },
#     {
#         "term": "性"
#     },
#     {
#         "term": "性衝動"
#     },
#     {
#         "term": "恥"
#     },
#     {
#         "term": "恥かしさ"
#     },
#     {
#         "term": "恥ずかしさ"
#     },
#     {
#         "term": "慙愧"
#     },
#     {
#         "term": "慚愧"
#     },
#     {
#         "term": "羞"
#     },
#     {
#         "term": "羞しさ"
#     },
#     {
#         "term": "羞恥"
#     },
#     {
#         "term": "赤恥"
#     },
#     {
#         "term": "シンパシー"
#     },
#     {
#         "term": "共感"
#     },
#     {
#         "term": "共鳴"
#     },
#     {
#         "term": "共鳴り"
#     },
#     {
#         "term": "同感"
#     },
#     {
#         "term": "御機嫌"
#     },
#     {
#         "term": "ご機嫌"
#     },
#     {
#         "term": "機嫌"
#     },
#     {
#         "term": "気分"
#     },
#     {
#         "term": "事"
#     },
#     {
#         "term": "事柄"
#     },
#     {
#         "term": "什"
#     },
#     {
#         "term": "代物"
#     },
#     {
#         "term": "物"
#     },
#     {
#         "term": "物事"
#     },
#     {
#         "term": "物件"
#     },
#     {
#         "term": "平気"
#     },
#     {
#         "term": "無関心"
#     },
#     {
#         "term": "ケース"
#     }
# ]

# %%
import json

import word2vec


synonyms = word2vec.get_synonyms('健康')
print(json.dumps(synonyms, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "衛生",
#         "similarity": 0.5829343199729919
#     },
#     {
#         "term": "心身",
#         "similarity": 0.5055596828460693
#     },
#     {
#         "term": "福祉",
#         "similarity": 0.48429426550865173
#     },
#     {
#         "term": "保健",
#         "similarity": 0.46757158637046814
#     },
#     {
#         "term": "介護",
#         "similarity": 0.46678638458251953
#     },
#     {
#         "term": "ケア",
#         "similarity": 0.4635636806488037
#     },
#     {
#         "term": "環境",
#         "similarity": 0.44540971517562866
#     },
#     {
#         "term": "精神",
#         "similarity": 0.43922868371009827
#     },
#     {
#         "term": "疾病",
#         "similarity": 0.43444526195526123
#     },
#     {
#         "term": "リハビリテーション",
#         "similarity": 0.426738977432251
#     }
# ]

# %%
import json

import word2vec


results = word2vec.analogy(('フランス', 'パリ'), '日本')
print(json.dumps(results, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "term": "東京",
#         "similarity": 0.5726803541183472
#     },
#     {
#         "term": "京都",
#         "similarity": 0.5042847394943237
#     },
#     {
#         "term": "北京",
#         "similarity": 0.46329930424690247
#     },
#     {
#         "term": "ロンドン",
#         "similarity": 0.4597439467906952
#     },
#     {
#         "term": "大阪",
#         "similarity": 0.4592345952987671
#     },
#     {
#         "term": "上海",
#         "similarity": 0.43720632791519165
#     },
#     {
#         "term": "ソウル",
#         "similarity": 0.4371134340763092
#     },
#     {
#         "term": "京第",
#         "similarity": 0.41076332330703735
#     },
#     {
#         "term": "ニューヨーク",
#         "similarity": 0.40882596373558044
#     },
#     {
#         "term": "ベルリン",
#         "similarity": 0.39789241552352905
#     }
# ]
